# %%
# !conda install Numpy
# Out:
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import pandas as pd

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in c:\users\user\anaconda3\lib\site-packages (18.0)

# %%
# !pip3 install Numpy

# %%
import numpy as np

# %%
df = pd.read_json('nobel_winners_plus_bornin.json')

# %%
df
# Out:
#      award_age                 born_in                category  \
# 0         57.0                    None  Physiology or Medicine
# 1         80.0                    None                   Peace
# 2         49.0                    None              Literature
# 3         59.0                    None                   Peace
# 4         49.0                    None  Physiology or Medicine
# 5         46.0                    None  Physiology or Medicine
# 6         48.0                    None                   Peace
# 7         75.0                    None  Physiology or Medicine
# 8         57.0          United Kingdom  Physiology or Medicine
# 9         60.0                  Russia               Chemistry
# 10        81.0                    None                 Physics
# 11        60.0                    None              Literature
# 12        46.0                    None  Physiology or Medicine
# 13        37.0                    None                 Physics
# ...

# %%
np.nan == np.nan
# Out:
# False

# %%
df.dropna()
# Out:
#      award_age                 born_in                category  \
# 8         57.0          United Kingdom  Physiology or Medicine
# 9         60.0                  Russia               Chemistry
# 29        77.0                 Germany                   Peace
# 58        43.0                 Hungary                 Physics
# 63        56.0                  Latvia               Chemistry
# 71        78.0                 Ukraine              Literature
# 72        65.0                 Belarus                   Peace
# 97        76.0                Bulgaria              Literature
# 104       87.0                  Poland                   Peace
# 119       39.0                 Germany  Physiology or Medicine
# 154       69.0               Lithuania              Literature
# 159       55.0                  Canada  Physiology or Medicine
# 167       73.0                   India                 Physics
# 176       57.0                   Italy  Physiology or Medicine
# ...

# %%
df[df.duplicated('name')].count()
# Out:
# award_age          4
# born_in           29
# category           4
# country            4
# date_of_birth      4
# date_of_death      4
# gender             4
# link              33
# name               4
# place_of_birth     4
# place_of_death     4
# text               4
# year               4
# dtype: int64

# %%
all_dupes = df[df.duplicated(‘name’)]/		# 행나눔표시. 중괄호,대괄호잇으면 굳이 안써도됨.
| df.duplicated(‘name’, keep='last')]
all_dupes.count()

# %%
df[df.drop_duplicated()]
