# %%
import pandas as pd
import numpy as np

# %%
# tab키로 분리시키는 옵션.

df = pd.read_csv('pew.txt', sep="\t")

# %%
df
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
df[df.religion=='Buddhist']
# Out:
#    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  $75-100k  \
# 2  Buddhist     27       21       30       34       33       58        62
#
#    $100-150k  >150k  Don't know/refused
# 2         39     53                  54

# %%
df[df.religion=='Buddhist'].mean(axis=1)
# Out:
# 2    41.1
# dtype: float64

# %% [markdown]
# # wide를 long으로 바꾸는 함수. melt()
# # groupby()

# %%
# 얼어잇는거 녹여서 슥~ 흘려보낸다는 의미.

df.melt('religion')
# Out:
#                     religion            variable  value
# 0                   Agnostic               <$10k     27
# 1                    Atheist               <$10k     12
# 2                   Buddhist               <$10k     27
# 3                   Catholic               <$10k    418
# 4         Don’t know/refused               <$10k     15
# 5           Evangelical Prot               <$10k    575
# 6                      Hindu               <$10k      1
# 7    Historically Black Prot               <$10k    228
# 8          Jehovah's Witness               <$10k     20
# 9                     Jewish               <$10k     19
# 10             Mainline Prot               <$10k    289
# 11                    Mormon               <$10k     29
# 12                    Muslim               <$10k      6
# 13                  Orthodox               <$10k     13
# 14           Other Christian               <$10k      9
# 15              Other Faiths               <$10k     20
# ...

# %%
melt_data = df[melt.religion=='Hindu']
???????????????????????????????????????????????????????????????????????????????????????
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6aa7df1a56e5> in <module>()
# ----> 1 df.melt[melt.religion=='Hindu']
#
# NameError: name 'melt' is not defined

# %%
melt_data = df.melt('religion')

# %%
melt_data.groupby('religion').mean()
# Out:
#                          value
# religion
# Agnostic                  82.6
# Atheist                   51.5
# Buddhist                  41.1
# Catholic                 805.4
# Don’t know/refused        27.2
# Evangelical Prot         947.2
# Hindu                     25.7
# Historically Black Prot  199.5
# Jehovah's Witness         21.5
# Jewish                    68.2
# Mainline Prot            747.0
# Mormon                    58.1
# Muslim                    11.6
# Orthodox                  36.3
# Other Christian           12.9
# Other Faiths              44.9
# Other World Religions      4.2
# Unaffiliated             370.7

# %%
melt_data.groupby('religion').max()
# Out:
#                                    variable  value
# religion
# Agnostic                 Don't know/refused    137
# Atheist                  Don't know/refused     76
# Buddhist                 Don't know/refused     62
# Catholic                 Don't know/refused   1489
# Don’t know/refused       Don't know/refused    116
# Evangelical Prot         Don't know/refused   1529
# Hindu                    Don't know/refused     54
# Historically Black Prot  Don't know/refused    339
# Jehovah's Witness        Don't know/refused     37
# Jewish                   Don't know/refused    162
# Mainline Prot            Don't know/refused   1328
# Mormon                   Don't know/refused    112
# Muslim                   Don't know/refused     23
# Orthodox                 Don't know/refused     73
# Other Christian          Don't know/refused     18
# Other Faiths             Don't know/refused     71
# Other World Religions    Don't know/refused      8
# ...

# %%
melt_data.groupby('religion').min()
# Out:
#                         variable  value
# religion
# Agnostic                 $10-20k     27
# Atheist                  $10-20k     12
# Buddhist                 $10-20k     21
# Catholic                 $10-20k    418
# Don’t know/refused       $10-20k     10
# Evangelical Prot         $10-20k    414
# Hindu                    $10-20k      1
# Historically Black Prot  $10-20k     78
# Jehovah's Witness        $10-20k      6
# Jewish                   $10-20k     19
# Mainline Prot            $10-20k    289
# Mormon                   $10-20k     29
# Muslim                   $10-20k      6
# Orthodox                 $10-20k     13
# Other Christian          $10-20k      7
# Other Faiths             $10-20k     20
# Other World Religions    $10-20k      2
# Unaffiliated             $10-20k    217

# %%
df = pd.read_csv('tb.csv')

# %%
df
# Out:
#      iso2  year   new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0      AD  1989      NaN         NaN          NaN          NaN           NaN
# 1      AD  1990      NaN         NaN          NaN          NaN           NaN
# 2      AD  1991      NaN         NaN          NaN          NaN           NaN
# 3      AD  1992      NaN         NaN          NaN          NaN           NaN
# 4      AD  1993     15.0         NaN          NaN          NaN           NaN
# 5      AD  1994     24.0         NaN          NaN          NaN           NaN
# 6      AD  1996      8.0         NaN          NaN          0.0           0.0
# 7      AD  1997     17.0         NaN          NaN          0.0           0.0
# 8      AD  1998      1.0         NaN          NaN          0.0           0.0
# 9      AD  1999      4.0         NaN          NaN          0.0           0.0
# 10     AD  2000      1.0         NaN          NaN          0.0           0.0
# ...

# %%
# melt() 함수의 인자가 여러개일땐, list로.
# pandas랑 똑같이.

df.melt(['iso2', 'year'])
# 변수만있고, 값이없어. NaN 없애기. dropNa
# Out:
#        iso2  year   variable  value
# 0        AD  1989     new_sp    NaN
# 1        AD  1990     new_sp    NaN
# 2        AD  1991     new_sp    NaN
# 3        AD  1992     new_sp    NaN
# 4        AD  1993     new_sp   15.0
# 5        AD  1994     new_sp   24.0
# 6        AD  1996     new_sp    8.0
# 7        AD  1997     new_sp   17.0
# 8        AD  1998     new_sp    1.0
# 9        AD  1999     new_sp    4.0
# 10       AD  2000     new_sp    1.0
# 11       AD  2001     new_sp    3.0
# 12       AD  2002     new_sp    2.0
# 13       AD  2003     new_sp    7.0
# 14       AD  2004     new_sp    3.0
# 15       AD  2005     new_sp    5.0
# 16       AD  2006     new_sp    8.0
# 17       AD  2007     new_sp    2.0
# 18       AD  2008     new_sp    3.0
# 19       AE  1980     new_sp    NaN
# 20       AE  1981     new_sp    NaN
# 21       AE  1982     new_sp    NaN
# 22       AE  1983     new_sp    NaN
# 23       AE  1984     new_sp    NaN
# 24       AE  1985     new_sp    NaN
# ...

# %%
# 컬럼명 바꾸기
data2 = df.melt(['iso2', 'year'], value_name="문", var_name = "근영")

# %%
# NaN없애기.
data2.dropna(inplace=True)

# %%
data2
# Out:
#        iso2  year         근영     문
# 0        AD  1989     new_sp   NaN
# 1        AD  1990     new_sp   NaN
# 2        AD  1991     new_sp   NaN
# 3        AD  1992     new_sp   NaN
# 4        AD  1993     new_sp  15.0
# 5        AD  1994     new_sp  24.0
# 6        AD  1996     new_sp   8.0
# 7        AD  1997     new_sp  17.0
# 8        AD  1998     new_sp   1.0
# 9        AD  1999     new_sp   4.0
# 10       AD  2000     new_sp   1.0
# 11       AD  2001     new_sp   3.0
# 12       AD  2002     new_sp   2.0
# 13       AD  2003     new_sp   7.0
# 14       AD  2004     new_sp   3.0
# 15       AD  2005     new_sp   5.0
# 16       AD  2006     new_sp   8.0
# 17       AD  2007     new_sp   2.0
# 18       AD  2008     new_sp   3.0
# 19       AE  1980     new_sp   NaN
# 20       AE  1981     new_sp   NaN
# 21       AE  1982     new_sp   NaN
# 22       AE  1983     new_sp   NaN
# 23       AE  1984     new_sp   NaN
# 24       AE  1985     new_sp   NaN
# 25       AE  1986     new_sp   NaN
# ...

# %%
df.groupby('year').sum()
#?????????????????????????????????????????????????????????????????????????????/
# Out:
#          new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# year
# 1980     8350.0         0.0          0.0         12.0          56.0
# 1981     7887.0         0.0          0.0          8.0          49.0
# 1982     7206.0         0.0          0.0          6.0          52.0
# 1983     7437.0         0.0          0.0          9.0          49.0
# 1984    11024.0         0.0          0.0          3.0          44.0
# 1985    13130.0         0.0          0.0         12.0          42.0
# 1986    14635.0         0.0          0.0          9.0          59.0
# 1987    21743.0         0.0          0.0          9.0          40.0
# 1988    24665.0         0.0          0.0          4.0          43.0
# 1989    25060.0         0.0          0.0         10.0          45.0
# 1990    28636.0         0.0          0.0          3.0          35.0
# 1991    29164.0         0.0          0.0          7.0          37.0
# 1992    32811.0         0.0          0.0          6.0          42.0
# ...

# %%
# multi index....
# 어디에 melt를 적용해야할까. column명에 변수적 개념인 애가 왔을때.!

# %% [markdown]
# # weather 데이터

# %%
df = pd.read_csv('weather.txt', sep="\t")

# %%
df
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
# 고정시킬것만 melt에 집어넣음됨.

df.melt(['id', 'year', 'element', 'month']).dropna()
# Out:
#               id  year element  month variable  value
# 20   MX000017004  2010    TMAX     12       d1  299.0
# 21   MX000017004  2010    TMIN     12       d1  138.0
# 24   MX000017004  2010    TMAX      2       d2  273.0
# 25   MX000017004  2010    TMIN      2       d2  144.0
# 40   MX000017004  2010    TMAX     11       d2  313.0
# 41   MX000017004  2010    TMIN     11       d2  163.0
# 46   MX000017004  2010    TMAX      2       d3  241.0
# 47   MX000017004  2010    TMIN      2       d3  144.0
# 56   MX000017004  2010    TMAX      7       d3  286.0
# 57   MX000017004  2010    TMIN      7       d3  175.0
# 84   MX000017004  2010    TMAX     11       d4  272.0
# 85   MX000017004  2010    TMIN     11       d4  120.0
# 92   MX000017004  2010    TMAX      3       d5  321.0
# 93   MX000017004  2010    TMIN      3       d5  142.0
# 102  MX000017004  2010    TMAX      8       d5  296.0
# 103  MX000017004  2010    TMIN      8       d5  158.0
# ...

# %%
df.id.unique()

# 헐 값이 하나밖에없넹. 의미가 없잖아! 그럼 지워버리자.
# Out:
# array(['MX000017004'], dtype=object)

# %%
#del df.id 는 안도미.
del df['id']

# %%
df
# Out:
#     year  month element     d1     d2     d3     d4     d5     d6     d7  \
# 0   2010      1    TMAX    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   2010      1    TMIN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2   2010      2    TMAX    NaN  273.0  241.0    NaN    NaN    NaN    NaN
# 3   2010      2    TMIN    NaN  144.0  144.0    NaN    NaN    NaN    NaN
# 4   2010      3    TMAX    NaN    NaN    NaN    NaN  321.0    NaN    NaN
# 5   2010      3    TMIN    NaN    NaN    NaN    NaN  142.0    NaN    NaN
# 6   2010      4    TMAX    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7   2010      4    TMIN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8   2010      5    TMAX    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9   2010      5    TMIN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
data3 = df.reset_index()

# %%
df = df[['year','month','element','variable','value']]

# column끼리 sorting하는방식.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-0bb6c3919464> in <module>()
# ----> 1 df = df[['year','month','element','variable','value']]
#       2
#       3 # column끼리 sorting하는방식.
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ...

# %%
df.year.unique()

# 아머야 얘도 2010년데이터만있네. but, 나중에 추가될것을 고려하여 없애진않음.
# Out:
# array([2010], dtype=int64)

# %%
df.sort_values('year', inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df[df.element == 'TMIN'].group_by('month')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-f06b99bdba01> in <module>()
# ----> 1 df[df.element == 'TMIN'].group_by('month')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'

# %%
# group by,  pivot, pivot table, cross tab 
# 총 groupby는 4개가 있음.

df.pivot_table(data3, index='month', value='value')

# arg function.
# data3. groupby('month').mean()
# pivot_table은 좀더 쉽게쓰기위함! group by로 다 해결됨~
# but, 내 입맛대로 컬럼명? 을 바꾸고싶을때.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-a62f8720426f> in <module>()
#       3 # 총 groupby는 4개가 있음.
#       4
# ----> 5 df.pivot_table(data3, index='month', value='value')
#
# TypeError: pivot_table() got an unexpected keyword argument 'value'

# %%
# wide format으로 통계값 구개보기.

# %% [markdown]
# # stack

# %%
df = pd.read_csv('pew.txt', sep='\t')
df.head()
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
df = df.set_index('religion')
print(df)
# Out:
#                          <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# religion
# Agnostic                    27       34       60       81       76      137
# Atheist                     12       27       37       52       35       70
# Buddhist                    27       21       30       34       33       58
# Catholic                   418      617      732      670      638     1116
# Don’t know/refused          15       14       15       11       10       35
# Evangelical Prot           575      869     1064      982      881     1486
# Hindu                        1        9        7        9       11       34
# Historically Black Prot    228      244      236      238      197      223
# Jehovah's Witness           20       27       24       24       21       30
# Jewish                      19       19       25       25       30       95
# Mainline Prot              289      495      619      655      651     1107
# ...

# %%
df = df.stack()

# %%
df
# 한 열로 쌓는거.
# melt랑 비슷하당.
# Out:
# religion
# Agnostic               <$10k                  27
#                        $10-20k                34
#                        $20-30k                60
#                        $30-40k                81
#                        $40-50k                76
#                        $50-75k               137
#                        $75-100k              122
#                        $100-150k             109
#                        >150k                  84
#                        Don't know/refused     96
# Atheist                <$10k                  12
#                        $10-20k                27
#                        $20-30k                37
#                        $30-40k                52
#                        $40-50k                35
#                        $50-75k                70
#                        $75-100k               73
#                        $100-150k              59
#                        >150k                  74
# ...

# %%
# 첫번째 열을 풀어헤치는거.
df.unstack()
# Out:
#                     religion
# <$10k               Agnostic                     27
#                     Atheist                      12
#                     Buddhist                     27
#                     Catholic                    418
#                     Don’t know/refused           15
#                     Evangelical Prot            575
#                     Hindu                         1
#                     Historically Black Prot     228
#                     Jehovah's Witness            20
#                     Jewish                       19
#                     Mainline Prot               289
#                     Mormon                       29
#                     Muslim                        6
#                     Orthodox                     13
#                     Other Christian               9
#                     Other Faiths                 20
#                     Other World Religions         5
# ...

# %%
df.index = df.index.rename('A')
df
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# A
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
a.rename('A')
df
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# A
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
# dict형태는 자동완성이 안된다.
a = df['<$10k']
df['<$10k'].rename
# Out:
# <bound method Series.rename of A
# 0      27
# 1      12
# 2      27
# 3     418
# 4      15
# 5     575
# 6       1
# 7     228
# 8      20
# 9      19
# 10    289
# 11     29
# 12      6
# 13     13
# 14      9
# 15     20
# 16      5
# 17    217
# Name: <$10k, dtype: int64>

# %%
df.name='frequency'

# 문자없이 숫자로만이루어져있으니까,

# %% [markdown]
# # astype

# %%
# tmax, tmin은 뭐람?
# category타입으로 바꾸기.

df.religion.astype('category')
# Out:
# A
# 0                    Agnostic
# 1                     Atheist
# 2                    Buddhist
# 3                    Catholic
# 4          Don’t know/refused
# 5            Evangelical Prot
# 6                       Hindu
# 7     Historically Black Prot
# 8           Jehovah's Witness
# 9                      Jewish
# 10              Mainline Prot
# 11                     Mormon
# 12                     Muslim
# 13                   Orthodox
# 14            Other Christian
# 15               Other Faiths
# 16      Other World Religions
# 17               Unaffiliated
# Name: religion, dtype: category
# Categories (18, object): [Agnostic, Atheist, Buddhist, Catholic, ..., Other Christian, Other Faiths, Other World Religions, Unaffiliated]

# %%
df.religion.str.cat
# Out:
# <bound method StringMethods.cat of <pandas.core.strings.StringMethods object at 0x00000162832DE438>>

# %%
df.religion.describe()
# Out:
# count                     18
# unique                    18
# top       Don’t know/refused
# freq                       1
# Name: religion, dtype: object

# %%
df.religion.cat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-d3d7dec86647> in <module>()
# ----> 1 df.religion.cat
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     130             # we're accessing the attribute of the class, i.e., Dataset.geo
#     131             return self._accessor
# --> 132         accessor_obj = self._accessor(obj)
#     133         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df.category.cat.codes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-c36b9057c36f> in <module>()
# ----> 1 df.category.cat.codes
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'category'

# %%
# 인코딩
# 1) one-hot 인코딩.
# 2) label인코딩(small=0, large=1)
